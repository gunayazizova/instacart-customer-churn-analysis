# %% [markdown]
# # Prediciting Churn rate for next 30 days

# %% [markdown]
# This notebook is implementing a predictive analysis model, that predicts the chrun rate for next 30 days based on Active and Inactive Customers.

# %% [markdown]
# ## How This Model Enhances Customer Shopping Experience?
#
# Using the churn predictions, Instacart could send targeted reminders or special offers to inactive customers. Offering discounts or exclusive deals to re-engage customers who haven't placed an order in a while.

# %%
import seaborn as sns
import numpy as np
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
# !pip install mplcursors
import mplcursors
# !pip install graphviz
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report
# !pip install google-cloud-bigquery
# !pip install pybigquery
# !pip install google-cloud-bigquery-storage
from google.cloud import bigquery
# !pip install pandas-gbq
from pandas_gbq import read_gbq, to_gbq
from sklearn import preprocessing 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import export_text, DecisionTreeRegressor, export_graphviz
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, classification_report, roc_auc_score,  mean_absolute_error, confusion_matrix
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from imblearn.over_sampling import SMOTE
from sklearn.cluster import KMeans
from imblearn.under_sampling import RandomUnderSampler
# Out:
# Requirement already satisfied: mplcursors in c:\users\gunay\anaconda3\lib\site-packages (0.6)
# Requirement already satisfied: matplotlib!=3.7.1,>=3.1 in c:\users\gunay\anaconda3\lib\site-packages (from mplcursors) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gunay\anaconda3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gunay\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.7.1,>=3.1->mplcursors) (1.16.0)
# Requirement already satisfied: graphviz in c:\users\gunay\anaconda3\lib\site-packages (0.20.3)
# Requirement already satisfied: google-cloud-bigquery in c:\users\gunay\anaconda3\lib\site-packages (3.27.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.11.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (2.23.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.36.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=20.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (24.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.25.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery) (1.67.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\gunay\anaconda3\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2024.8.30)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gunay\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: pybigquery in c:\users\gunay\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlalchemy>=1.1.9 in c:\users\gunay\anaconda3\lib\site-packages (from pybigquery) (2.0.34)
# Requirement already satisfied: google-cloud-bigquery>=1.6.0 in c:\users\gunay\anaconda3\lib\site-packages (from pybigquery) (3.27.0)
# Requirement already satisfied: future in c:\users\gunay\anaconda3\lib\site-packages (from pybigquery) (1.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.11.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (2.23.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (2.36.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (2.7.2)
# Requirement already satisfied: packaging>=20.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (24.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery>=1.6.0->pybigquery) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\gunay\anaconda3\lib\site-packages (from sqlalchemy>=1.1.9->pybigquery) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gunay\anaconda3\lib\site-packages (from sqlalchemy>=1.1.9->pybigquery) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (1.25.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=1.6.0->pybigquery) (1.67.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery>=1.6.0->pybigquery) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery>=1.6.0->pybigquery) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery>=1.6.0->pybigquery) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery>=1.6.0->pybigquery) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\gunay\anaconda3\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery>=1.6.0->pybigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery>=1.6.0->pybigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery>=1.6.0->pybigquery) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery>=1.6.0->pybigquery) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery>=1.6.0->pybigquery) (2024.8.30)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gunay\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery>=1.6.0->pybigquery) (0.4.8)
# Requirement already satisfied: google-cloud-bigquery-storage in c:\users\gunay\anaconda3\lib\site-packages (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (2.23.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery-storage) (2.36.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery-storage) (1.25.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery-storage) (5.28.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (1.67.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery-storage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery-storage) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery-storage) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gunay\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery-storage) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-storage) (2024.8.30)
# Requirement already satisfied: pandas-gbq in c:\users\gunay\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: setuptools in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (75.1.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (1.3.1)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (1.26.4)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (2.2.2)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (16.1.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (1.8.2)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.10.2 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (2.23.0)
# Requirement already satisfied: google-auth>=2.13.0 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (2.36.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (1.2.1)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=3.4.2 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (3.27.0)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from pandas-gbq) (24.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (1.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth>=2.13.0->pandas-gbq) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth>=2.13.0->pandas-gbq) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth>=2.13.0->pandas-gbq) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (2.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\gunay\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gunay\anaconda3\lib\site-packages (from pandas>=1.1.4->pandas-gbq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gunay\anaconda3\lib\site-packages (from pandas>=1.1.4->pandas-gbq) (2023.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\gunay\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.67.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\gunay\anaconda3\lib\site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gunay\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.13.0->pandas-gbq) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\gunay\anaconda3\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gunay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gunay\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.2.2)

# %%
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\Gunay\Desktop\instacart testing\instacart-441209-84de4dcbf601.json"
# Create the connection to BigQuery
project_id = 'instacart-441209'
DATABASE_URI = f'bigquery://{project_id}'
engine = create_engine(DATABASE_URI)
# Out:
# C:\Users\Gunay\AppData\Local\Temp\ipykernel_13148\2937497850.py:7: SADeprecationWarning: The dbapi() classmethod on dialect classes has been renamed to import_dbapi().  Implement an import_dbapi() classmethod directly on class <class 'pybigquery.sqlalchemy_bigquery.BigQueryDialect'> to remove this warning; the old .dbapi() classmethod may be maintained for backwards compatibility.
#   engine = create_engine(DATABASE_URI)

# %% [markdown]
# ## What percentage of customers have churned in the last 30 days?

# %%
# Query to get the max days since prior order for each user
customer_activity_query = """
SELECT user_id, MAX(days_since_prior_order) AS max_days_since_prior
FROM `instacart-441209.instacart.orders`
GROUP BY user_id
"""

# Read data into DataFrame
customer_activity_df = pd.read_sql(customer_activity_query, engine)

inactive_customers = customer_activity_df[customer_activity_df['max_days_since_prior'] >= 30]
active_customers = customer_activity_df[customer_activity_df['max_days_since_prior'] < 30]

# Count of inactive and active customers
inactive_customers_30_days_count = inactive_customers['user_id'].nunique()
active_customers_30_days_count = active_customers['user_id'].nunique()

# Query to get total number of customers
total_customers_query = """
SELECT COUNT(DISTINCT user_id) AS total_customers
FROM `instacart-441209.instacart.orders`
"""

# Get the total number of unique customers
total_customers_df = pd.read_sql(total_customers_query, engine)
total_customers = total_customers_df['total_customers'][0]

# Calculate churn rate and active rate
churn_rate_30_days = (inactive_customers_30_days_count / total_customers) * 100
active_rate_30_days = (active_customers_30_days_count / total_customers) * 100

# Print results
print(f"Total number of unique customers: {total_customers}")
print(f"Number of active customers in the last 30 days: {active_customers_30_days_count}")
print(f"Number of inactive customers in the last 30 days: {inactive_customers_30_days_count}")
print(f"Churn rate for the last 30 days: {churn_rate_30_days:.2f}%")
print(f"Active rate for the last 30 days: {active_rate_30_days:.2f}%")

# Prepare results for CSV
results_df = pd.DataFrame({
    "Total_Customers": [total_customers],
    "Active_Customers_30_Days": [active_customers_30_days_count],
    "Inactive_Customers_30_Days": [inactive_customers_30_days_count],
    "Churn_Rate_30_Days": [churn_rate_30_days],
    "Active_Rate_30_Days": [active_rate_30_days]
})

# Save results to CSV
results_df.to_csv(r"C:\Users\Gunay\Documents\customer_churn_analysis.csv")
print("Results have been saved to customer_churn_analysis.csv")
# Out:
# Total number of unique customers: 206209
# Number of active customers in the last 30 days: 54197
# Number of inactive customers in the last 30 days: 152012
# Churn rate for the last 30 days: 73.72%
# Active rate for the last 30 days: 26.28%
# Results have been saved to customer_churn_analysis.csv

# %%
# Data for plotting
categories = ['Active Customers', 'Inactive Customers']
counts = [active_customers_30_days_count, inactive_customers_30_days_count]
percentages = [active_rate_30_days, churn_rate_30_days]

# Create the plot
plt.figure(figsize=(8, 5))
bars = plt.bar(categories, counts, color=['blue', 'lightpink'])
plt.title('Active vs Inactive Customers (Last 30 Days)', fontsize=14)
plt.xlabel('Customer Status', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)
for i, bar in enumerate(bars):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 50, f'{percentages[i]:.2f}%', ha='center', va='bottom', fontsize=12)
plt.show()

# %% [markdown]
# # Future churn percentages

# %% [markdown]
# ### Feature Engineering:
# We calculate days_since_last_order, which represents how many days have passed since the customer's last order.
# The churned column is created by checking if the days_since_last_order is greater than the churn_threshold (30 days).

# %%
from sklearn.preprocessing import LabelEncoder
query = """
SELECT
    op.order_id,
    op.product_id,
    op.add_to_cart_order,
    op.reordered,
    p.product_name,
    p.aisle_id,
    p.department_id,
    a.aisle,
    d.department,
    o.user_id,
    o.eval_set,
    o.order_number,
    o.order_dow,
    o.order_hour_of_day,
    o.days_since_prior_order
FROM
    `instacart-441209.instacart.order_products_train` AS op
JOIN
    `instacart-441209.instacart.products` AS p
    ON op.product_id = p.product_id
JOIN
    `instacart-441209.instacart.aisles` AS a
    ON p.aisle_id = a.aisle_id
JOIN
    `instacart-441209.instacart.departments` AS d
    ON p.department_id = d.department_id
JOIN
    `instacart-441209.instacart.orders` AS o
    ON op.order_id = o.order_id
LEFT JOIN
    `instacart-441209.instacart.order_products_prior` AS op_prior
    ON op_prior.order_id = op.order_id AND op_prior.product_id = op.product_id
"""

# Data into a DataFrame
combined_df = pd.read_sql(query, engine)
combined_df['days_since_prior_order'].fillna(0, inplace=True)

# Drop non-numeric columns and handle categorical features (encode them)
categorical_columns = ['product_name', 'eval_set']
for col in categorical_columns:
    le = LabelEncoder()
    combined_df[col] = le.fit_transform(combined_df[col])

# Encode 'aisle' and 'department' columns using get_dummies()
combined_df = pd.get_dummies(combined_df, columns=['aisle', 'department', 'eval_set'], drop_first=True)

churn_threshold = 30
combined_df['Churn'] = (combined_df['days_since_prior_order'] >= churn_threshold).astype(int)
combined_df['Churn'].fillna(0, inplace=True)
print(combined_df['Churn'].unique())
# Out:
# C:\Users\Gunay\AppData\Local\Temp\ipykernel_13148\2184420375.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df['days_since_prior_order'].fillna(0, inplace=True)
# [1 0]
# C:\Users\Gunay\AppData\Local\Temp\ipykernel_13148\2184420375.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df['Churn'].fillna(0, inplace=True)

# %% [markdown]
# ## Correlation matrix

# %%
correlation_matrix = combined_df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plot the correlation matrix with a different color palette
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt='.2f', cbar=True, linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
# Out:
# Correlation Matrix:
#                           order_id  product_id  add_to_cart_order  reordered  \
# order_id                  1.000000   -0.000545           0.001916   0.001418
# product_id               -0.000545    1.000000           0.003128   0.006560
# add_to_cart_order         0.001916    0.003128           1.000000  -0.146393
# reordered                 0.001418    0.006560          -0.146393   1.000000
# product_name             -0.000596    0.021362           0.017049  -0.000329
# ...                            ...         ...                ...        ...
# department_personal care  0.002462   -0.012871           0.006220  -0.067111
# department_pets           0.000553   -0.007874          -0.006290   0.003680
# department_produce       -0.001792    0.067406          -0.028523   0.087221
# department_snacks         0.001704   -0.005789           0.033189  -0.010772
# Churn                    -0.001774    0.000467          -0.007771  -0.159577
#
#                           product_name  aisle_id  department_id   user_id  \
# order_id                     -0.000596 -0.000814       0.002708 -0.000867
# product_id                    0.021362 -0.001932      -0.027212 -0.001014
# add_to_cart_order             0.017049  0.010887       0.027428  0.000739
# reordered                    -0.000329 -0.000172      -0.050294 -0.004316
# product_name                  1.000000  0.130547       0.065034 -0.000725
# ...                                ...       ...            ...       ...
# department_personal care     -0.009018 -0.033611       0.023193 -0.000704
# department_pets              -0.010918 -0.045935      -0.016689  0.000253
# department_produce           -0.034322 -0.112812      -0.600949 -0.000689
# department_snacks            -0.015682 -0.012413       0.446074 -0.000898
# Churn                        -0.000292  0.004218       0.005650  0.004768
#
#                           order_number  order_dow  ...  \
# order_id                      0.001522   0.001090  ...
# product_id                   -0.001463  -0.003597  ...
# add_to_cart_order             0.014332  -0.019353  ...
# reordered                     0.223947  -0.006714  ...
# product_name                  0.010225  -0.002146  ...
# ...                                ...        ...  ...
# department_personal care     -0.009489   0.005480  ...
# department_pets              -0.005381   0.007231  ...
# department_produce            0.025927  -0.023581  ...
# department_snacks             0.003707   0.005324  ...
# Churn                        -0.288733  -0.015296  ...
#
#                           department_international  department_meat seafood  \
# order_id                                 -0.000465                 0.000339
# product_id                               -0.016566                -0.019406
# add_to_cart_order                         0.021448                 0.004297
# reordered                                -0.041536                -0.002362
# product_name                              0.020107                -0.058936
# ...                                            ...                      ...
# department_personal care                 -0.011714                -0.018818
# department_pets                          -0.005315                -0.008539
# department_produce                       -0.060299                -0.096872
# department_snacks                        -0.028534                -0.045842
# Churn                                     0.003558                 0.000299
#
#                           department_missing  department_other  \
# order_id                           -0.000277          0.000734
# product_id                         -0.002476          0.002641
# add_to_cart_order                   0.010073         -0.001164
# reordered                          -0.034286         -0.015457
# product_name                        0.010770         -0.001250
# ...                                      ...               ...
# department_personal care           -0.009740         -0.004532
# department_pets                    -0.004420         -0.002057
# department_produce                 -0.050139         -0.023331
# department_snacks                  -0.023726         -0.011041
# Churn                              -0.012211         -0.000395
#
#                           department_pantry  department_personal care  \
# order_id                           0.000157                  0.002462
# product_id                        -0.006003                 -0.012871
# add_to_cart_order                  0.045636                  0.006220
# reordered                         -0.119950                 -0.067111
# product_name                      -0.012211                 -0.009018
# ...                                     ...                       ...
# department_personal care          -0.031407                  1.000000
# department_pets                   -0.014251                 -0.007181
# department_produce                -0.161675                 -0.081462
# department_snacks                 -0.076507                 -0.038549
# Churn                              0.012442                  0.007840
#
#                           department_pets  department_produce  \
# order_id                         0.000553           -0.001792
# product_id                      -0.007874            0.067406
# add_to_cart_order               -0.006290           -0.028523
# reordered                        0.003680            0.087221
# product_name                    -0.010918           -0.034322
# ...                                   ...                 ...
# department_personal care        -0.007181           -0.081462
# department_pets                  1.000000           -0.036965
# department_produce              -0.036965            1.000000
# department_snacks               -0.017492           -0.198442
# Churn                           -0.000382           -0.020025
#
#                           department_snacks     Churn
# order_id                           0.001704 -0.001774
# product_id                        -0.005789  0.000467
# add_to_cart_order                  0.033189 -0.007771
# reordered                         -0.010772 -0.159577
# product_name                      -0.015682 -0.000292
# ...                                     ...       ...
# department_personal care          -0.038549  0.007840
# department_pets                   -0.017492 -0.000382
# department_produce                -0.198442 -0.020025
# department_snacks                  1.000000 -0.003913
# Churn                             -0.003913  1.000000
#
# [166 rows x 166 columns]

# %% [markdown]
# ## Define feature and target

# %%
features = combined_df.drop(columns=['days_since_prior_order', 'product_name', 'Churn'])
target = combined_df['Churn']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## XGBoost Classifier

# %%
import xgboost as xgb

# Initialize and train the XGBoost classifier (since churn is now a binary target)
model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=100, max_depth=5)
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = (y_pred == y_test).mean()
print(f"Accuracy: {accuracy:.2f}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Greens", cbar=False,
            xticklabels=["Not Churned", "Churned"], yticklabels=["Not Churned", "Churned"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.72
# [[185180  10262]
#  [ 67168  14314]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.95      0.83    195442
#            1       0.58      0.18      0.27     81482
#
#     accuracy                           0.72    276924
#    macro avg       0.66      0.56      0.55    276924
# weighted avg       0.69      0.72      0.66    276924

# %%
# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, columns=["Predicted 0", "Predicted 1"], index=["Actual 0", "Actual 1"])
conf_matrix_df.to_csv(r"C:\Users\Gunay\Documents\confusion_matrix_churn_rate.csv")

# %% [markdown]
# ### KNN Model

# %%
normalizer = MinMaxScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# Set up K-Nearest Neighbors Classifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train_norm, y_train)

# Predict on the test set
y_pred = knn.predict(X_test_norm)

# Calculate accuracy
knn_accuracy = accuracy_score(y_test, y_pred)
print("KNN Model Accuracy:", knn_accuracy)

# %% [markdown]
# ### Decision Tress

# %%
tree_clf = DecisionTreeClassifier(max_depth=10)
tree_clf.fit(X_train_norm, y_train)

pred = tree_clf.predict(X_test_norm)
print("MAE:", mean_absolute_error(pred, y_test))
print("RMSE:", mean_squared_error(pred, y_test, squared=False))
print("Accuracy:", tree_clf.score(X_test_norm, y_test))
# Out:
# MAE: 0.0
# RMSE: 0.0
# Accuracy: 1.0
# Predicted churn rate for the next 30 days: 100.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ### Logistic Regression

# %%
og_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Predict classes on the test set
y_pred_class = log_reg.predict(X_test)

# Classification metrics
accuracy_log_reg = accuracy_score(y_test, y_pred_class)
conf_matrix_log_reg = confusion_matrix(y_test, y_pred_class)
class_report_log_reg = classification_report(y_test, y_pred_class)
roc_auc_log_reg = roc_auc_score(y_test, log_reg.predict_proba(X_test)[:, 1])

print("\nLogistic Regression Results:")
print(f'Accuracy: {accuracy_log_reg * 100:.2f}%')
print("Confusion Matrix:")
print(conf_matrix_log_reg)
print("Classification Report:")
print(class_report_log_reg)
print(f'ROC AUC Score: {roc_auc_log_reg:.2f}')
# Out:
# Logistic Regression Results:
# Accuracy: 100.00%
# Confusion Matrix:
# [[16179     0]
#  [    0 45684]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16179
#         True       1.00      1.00      1.00     45684
#
#     accuracy                           1.00     61863
#    macro avg       1.00      1.00      1.00     61863
# weighted avg       1.00      1.00      1.00     61863
#
# ROC AUC Score: 1.00
# Predicted churn rate for the next 30 days: 99.99%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Random Forest Classifier

# %%
# Initialize and train Random Forest model
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train, y_train)

# Predict churn on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Random Forest Model Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)

# Predict churn rate for the next 30 days based on Random Forest model
predicted_churn_prob = rf_model.predict_proba([[30, 1/30]])[0][1] * 100
print(f"Predicted churn rate for the next 30 days (Random Forest): {predicted_churn_prob:.2f}%")
# Out:
# Random Forest Model Accuracy: 100.00%
# Confusion Matrix:
# [[16179     0]
#  [    0 45684]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16179
#         True       1.00      1.00      1.00     45684
#
#     accuracy                           1.00     61863
#    macro avg       1.00      1.00      1.00     61863
# weighted avg       1.00      1.00      1.00     61863
#
# Predicted churn rate for the next 30 days (Random Forest): 100.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Oversampling with SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check the class distribution after resampling
print("Class distribution after SMOTE:", y_train_resampled.value_counts())

# Initialize and train the Random Forest model on the resampled data
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train_resampled, y_train_resampled)

# Predict churn on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Random Forest Model Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)

sample_input = [[30, 1/30]]
predicted_churn_prob = rf_model.predict_proba(sample_input)[0][1] * 100
print(f"Predicted churn rate for the next 30 days: {predicted_churn_prob:.2f}%")
# Out:
# Class distribution after SMOTE: is_churn
# True     106328
# False    106328
# Name: count, dtype: int64
# Random Forest Model Accuracy: 100.00%
# Confusion Matrix:
# [[16179     0]
#  [    0 45684]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16179
#         True       1.00      1.00      1.00     45684
#
#     accuracy                           1.00     61863
#    macro avg       1.00      1.00      1.00     61863
# weighted avg       1.00      1.00      1.00     61863
#
# Predicted churn rate for the next 30 days: 100.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Undersampling

# %%
# Initialize RandomUnderSampler and apply it to the training set
rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

# Check the class distribution after undersampling
print("Class distribution after undersampling:", y_train_resampled.value_counts())

# Initialize and train Random Forest model on resampled data
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train_resampled, y_train_resampled)

# Predict churn on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Random Forest Model Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)

# Predict churn rate for the next 30 days based on Random Forest model
predicted_churn_prob = rf_model.predict_proba([[30, 1/30]])[0][1] * 100
print(f"Predicted churn rate for the next 30 days: {predicted_churn_prob:.2f}%")
# Out:
# Class distribution after undersampling: is_churn
# False    38018
# True     38018
# Name: count, dtype: int64
# Random Forest Model Accuracy: 100.00%
# Confusion Matrix:
# [[16179     0]
#  [    0 45684]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16179
#         True       1.00      1.00      1.00     45684
#
#     accuracy                           1.00     61863
#    macro avg       1.00      1.00      1.00     61863
# weighted avg       1.00      1.00      1.00     61863
#
# Predicted churn rate for the next 30 days: 100.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Add Cluster-Based Features

# %%
customer_activity_df['is_churn'] = customer_activity_df['max_days_since_prior'] >= 30

# Select features for clustering and target variable
X_clustering = customer_activity_df[['max_days_since_prior', 'order_frequency']]
y = customer_activity_df['is_churn']

# Determine the number of clusters (e.g., 3 clusters)
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
customer_activity_df['cluster'] = kmeans.fit_predict(X_clustering)

# Add the new 'cluster' feature to your main dataset
X = customer_activity_df[['max_days_since_prior', 'order_frequency', 'cluster']]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the Random Forest model
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train, y_train)

# Predict churn on the test set
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Random Forest Model Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)

# Predict churn rate for the next 30 days based on Random Forest model
predicted_churn_prob = rf_model.predict_proba([[30, 1/30, 1]])[0][1] * 100
print(f"Predicted churn rate for the next 30 days (with clustering): {predicted_churn_prob:.2f}%")
# Out:
# Random Forest Model Accuracy: 100.00%
# Confusion Matrix:
# [[16179     0]
#  [    0 45684]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16179
#         True       1.00      1.00      1.00     45684
#
#     accuracy                           1.00     61863
#    macro avg       1.00      1.00      1.00     61863
# weighted avg       1.00      1.00      1.00     61863
#
# Predicted churn rate for the next 30 days (with clustering): 72.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
gb_clf = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_clf.fit(X_train, y_train)

# Predict probabilities on the test set
y_pred_proba = gb_clf.predict_proba(X_test)[:, 1]  # Use probabilities for the positive class

# For regression metrics, use predicted probabilities instead of class predictions
mse_gb = mean_squared_error(y_test, y_pred_proba)  # Use probabilities for MSE
r2_gb = r2_score(y_test, y_pred_proba)  # Use probabilities for R^2
print("\nGradient Boosting Classifier Results:")
print(f'Mean Squared Error: {mse_gb:.2f}')
print(f'R^2 Score: {r2_gb:.2f}')

# Predicted churn probability for a specific input
input_features = [[30, 1/30, 1]] 
predicted_churn_prob = gb_clf.predict_proba(input_features)[0][1] * 100
print(f"Predicted churn rate for the next 30 days: {predicted_churn_prob:.2f}%")
# Out:
# Gradient Boosting Classifier Results:
# Mean Squared Error: 0.00
# R^2 Score: 1.00
# Predicted churn rate for the next 30 days: 100.00%
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Ada Boost Regressor

# %%
# Base model
base_model = DecisionTreeRegressor(max_depth=3)  

# AdaBoost model
ada_model = AdaBoostRegressor(estimator=base_model, n_estimators=50, random_state=42)
ada_model.fit(X_train, y_train)

# Predictions on the test set
y_pred_ada = ada_model.predict(X_test)

# Calculate regression metrics
mse_ada = mean_squared_error(y_test, y_pred_ada)
r2_ada = r2_score(y_test, y_pred_ada)
print("\nAdaptive Boosting Results:")
print(f'Mean Squared Error: {mse_ada:.2f}')
print(f'R^2 Score: {r2_ada:.2f}')

# Predicted churn probability (just predicted value, not a probability)
predicted_churn_value = ada_model.predict([[30, 1/30, 1]])[0]  # Single prediction
print(f"Predicted churn value for the next 30 days: {predicted_churn_value:.2f}")
# Out:
# Adaptive Boosting Results:
# Mean Squared Error: 0.00
# R^2 Score: 1.00
# Predicted churn value for the next 30 days: 1.00
# /opt/anaconda3/envs/bigquery-env/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
# Make predictions for the next 30 days
predicted_churn_df = customer_activity_df.copy()
predicted_churn_df['churn_prediction'] = model.predict(features)

# Calculate predicted churn rate
predicted_churn_customers = predicted_churn_df[predicted_churn_df['churn_prediction'] == 1]
predicted_churn_rate = (predicted_churn_customers['user_id'].nunique() / total_customers) * 100

# Print the predicted churn rate for the next 30 days
print("\nPredicted Churn rate for next 30 days:", predicted_churn_rate)
# Out:
# Predicted Churn rate for next 30 days: 73.71744201271525
